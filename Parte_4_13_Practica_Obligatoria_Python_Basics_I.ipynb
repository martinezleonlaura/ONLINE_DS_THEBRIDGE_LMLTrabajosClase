# %% [markdown]
# <a href="https://colab.research.google.com/github/martinezleonlaura/ONLINE_DS_THEBRIDGE_LMLTrabajosClase/blob/main/Parte_4_13_Practica_Obligatoria_Python_Basics_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: PYTHON

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste en dos ejercicios de programación libre a completar.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
# ## PARTE I
#
# En este ejercicio debes simular un chatbot al que le haremos pedidos de pizzas.
#
# 1. El chatbot tiene que saludar con un: "Buenas tardes, bienvenido al servicio de pedido online, el precio de nuestra pizzas es de 8,95 para la familiar o de 9,90 para la mediana ¿Cuántas pizzas  familiares desea?"
# 2. El ususario tiene que introducir un número de pizzas en una variable llamada 'pizz_familiar'
# 3. El chatbot debe responder: "Estupendo, ¿cuántas pizzas medianas desea?" y guardar el número de pizzas medianas en otra variable 'pizz_mediana'
# 4. Además debe responder del chatbot: "Estupendo, se están preparando 'pizz' pizzas familiares y 'pizz_mediana' pizzas medianas. Digame su dirección"
# 5. El ususario tiene que introducir una direccion en formato String en otra variable llamada 'direcc'
# 6. El programa debe calcular el monto total
# 7. Respuesta final del chatbot: "Le mandaremos las '(número total de pizzas)' pizzas a la dirección 'direcc'. Serán <precio total a pagar en euros>. Muchas gracias por su pedido."

# %%
pizz_familiar = input("Buenas tardes, bienvenido al servicio de pedido online, el precio de nuestra pizzas es de 8,95 para la familiar o de 9,90 para la mediana ¿Cuántas pizzas familiares desea? ")

pizz_mediana = input("Estupendo, ¿cuántas pizzas medianas desea? ")

direcc = input ("Estupendo, se están preparando " + pizz_familiar +  " pizzas familiares y " + pizz_mediana + " pizzas medianas. Digame su dirección. ")

pizz_familiar = float (pizz_familiar) # Paso a real para poder operar
pizz_mediana = float (pizz_mediana)

num_pizz_total = int (pizz_familiar + pizz_mediana) # Paso a entero, ya que las pizzas se venden por unidades enteras
#print (num_pizz_total)


precio_pizz_familiar = 8.95
precio_pizz_mediana = 9.90

precio_total = pizz_familiar  *precio_pizz_familiar + pizz_mediana * precio_pizz_mediana
#print (precio_total)

print ("Le mandaremos las" ,str(num_pizz_total), "pizzas a la dirección " + direcc + ". Serán" ,str(precio_total), "€. Muchas gracias por su pedido.") # Paso a str para poder concatenar
# Out:
# Buenas tardes, bienvenido al servicio de pedido online, el precio de nuestra pizzas es de 8,95 para la familiar o de 9,90 para la mediana ¿Cuántas pizzas familiares desea? 2
# Estupendo, ¿cuántas pizzas medianas desea? 3
# Estupendo, se están preparando 2 pizzas familiares y 3 pizzas medianas. Digame su dirección. Gran Vía, 72
# Le mandaremos las 5 pizzas a la dirección Gran Vía, 72. Serán 47.6 €. Muchas gracias por su pedido.

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
# ## Parte II
#
# Crea un programa que realice las siguientes acciones:
#
# 1. Solicite al usuario que introduzca 3 números enteros separados por **comas** (por ejemplo: 1,2,3).
# 2. Convierta esa entrada en una lista de números enteros.
# 3. Utilizando funciones built-in, determine el número máximo, el número mínimo y la suma total de los números introducidos.
# 4. Determine la verdad o falsedad de la siguiente afirmación: "El número máximo menos el número mínimo es igual a la suma total dividida por 5".
# 5. Muestre los resultados utilizando print.

# %%
numeros_str = input ("Introduzca 3 números enteros separados por comas ") # Input siempre lo va a recoger como str

lista_numeros_str = numeros_str.split(",") # Ya tengo la lista pero es una lista de str y tengo que pasar a int

lista_numeros_int = [] # Introduzco esta línea de código con una lista vacía, porque si no cada vez que ejecuto se iban añadiendo número. Así siempre parto de una lista vacía

for elemento in lista_numeros_str:
    numero_int = int(elemento)
    lista_numeros_int.append(numero_int)

#maximo = max(lista_numeros_int)
#print ("El número máximo es:",maximo)
minimo = min(lista_numeros_int)
print ("El número mínimo es:",minimo)
suma = sum(lista_numeros_int)
print ("El valor de la suma es:",suma)

rdo_afirmacion= (maximo - minimo) == (suma / 5)
print ("El número máximo menos el número mínimo es igual a la suma total dividida por 5:", rdo_afirmacion)
# Out:
# Introduzca 3 números enteros separados por comas 1,2,3
# El número mínimo es: 1
# El valor de la suma es: 6
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_906/2376354211.py in <cell line: 0>()
#      16 print ("El valor de la suma es:",suma)
#      17
# ---> 18 rdo_afirmacion= (maximo - minimo) == (suma / 5)
#      19 print ("El número máximo menos el número mínimo es igual a la suma total dividida por 5:", rdo_afirmacion)
#      20
#
# NameError: name 'maximo' is not defined
